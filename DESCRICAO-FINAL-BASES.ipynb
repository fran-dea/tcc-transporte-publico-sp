# %%
import pandas as pd

# %%
print("Histórico com dados das rotas")
df=pd.read_parquet("dados/rotaaas_historico.parquet")
print("Tamanho da tabela:", df.shape,'\n',
"Período contemplado:",min(df['data_referencia']), "-",max(df['data_referencia']))

print(df.info())
# Out:
# Histórico com dados das rotas
# Tamanho da tabela: (167346, 8)
#  Período contemplado: 201501 - 202503
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167346 entries, 0 to 167345
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   route_id          167346 non-null  object
#  1   agency_id         167346 non-null  int64
#  2   route_short_name  167346 non-null  object
#  3   route_long_name   167346 non-null  object
#  4   route_type        167346 non-null  int64
#  5   route_color       126052 non-null  object
#  6   route_text_color  124999 non-null  object
#  7   data_referencia   167346 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 10.2+ MB
# None

# %%
print("Histórico com dados das paradas")
df=pd.read_parquet("dados/viagens_historico.parquet")
print("Tamanho da tabela:", df.shape,'\n',
"Período contemplado:",min(df['data_referencia']), "-",max(df['data_referencia']))

print(df.info())
# Out:
# Histórico com dados das paradas
# Tamanho da tabela: (11849701, 13)
#  Período contemplado: 201501 - 202503
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11849701 entries, 0 to 11849700
# Data columns (total 13 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   route_id         object
#  1   service_id       object
#  2   trip_id          object
#  3   trip_headsign    object
#  4   direction_id     int64
#  5   shape_id         int64
#  6   data_referencia  object
#  7   stop_id          int64
#  8   stop_sequence    int64
#  9   stop_name        object
#  10  stop_desc        object
#  11  stop_lat         float64
#  12  stop_lon         float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 1.1+ GB
# None

# %%
print("Histórico com dados dos passageiros")
df=pd.read_parquet("dados/passageiros_unificado.parquet")
print("Tamanho da tabela:", df.shape,'\n',
"Período contemplado:",min(df['data']), "-",max(df['data']))

print(df.info())
# Out:
# Histórico com dados dos passageiros
# Tamanho da tabela: (4937029, 25)
#  Período contemplado: 2015-01-01 00:00:00 - 2025-12-03 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4937029 entries, 0 to 4937028
# Data columns (total 25 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   data                                      datetime64[ns]
#  1   tipo                                      object
#  2   area                                      object
#  3   empresa                                   object
#  4   linha                                     object
#  5   passageiros_dinheiro                      Int64
#  6   passageiros_comum                         Int64
#  7   passageiros_comum_mensal                  Int64
#  8   passageiros_estudante                     Int64
#  9   passageiros_estudante_mensal              Int64
#  10  passageiros_vale_transporte               Int64
# ...

# %%
import geopandas as gpd


print("População por bairro com base no censo de 2022 do IBGE")
df = gpd.read_file("dados/POPULAÇÃO-CENSO-2022-IBGE/BR_bairros_CD2022.zip")
print("Tamanho da tabela:", df.shape,'\n'
)

print(df.info())

print("Zonas de SP")
df = pd.read_excel("dados/tabela_regioes_sp.xlsx")
print("Tamanho da tabela:", df.shape,'\n'
)

print(df.info())
# Out:
# População por bairro com base no censo de 2022 do IBGE
# Tamanho da tabela: (17576, 27)
#
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 17576 entries, 0 to 17575
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CD_REGIAO   17576 non-null  object
#  1   NM_REGIAO   17576 non-null  object
#  2   CD_UF       17576 non-null  object
#  3   NM_UF       17576 non-null  object
#  4   CD_MUN      17576 non-null  object
#  5   NM_MUN      17576 non-null  object
#  6   CD_DIST     17576 non-null  object
#  7   NM_DIST     17576 non-null  object
#  8   CD_SUBDIST  17576 non-null  object
#  9   NM_SUBDIST  2973 non-null   object
#  10  CD_BAIRRO   17576 non-null  object
#  11  NM_BAIRRO   17576 non-null  object
#  12  CD_RGINT    17576 non-null  object
#  13  NM_RGINT    17576 non-null  object
#  14  CD_RGI      17576 non-null  object
#  15  NM_RGI      17576 non-null  object
# ...

# %%
import geopandas as gpd


print("Estações de metrô")
df = gpd.read_file("dados/GEOSAMPA-MAPA-TREM-E-METRO-SP/estacao_metro.geojson")
print("Tamanho da tabela:", df.shape,'\n'
)
print(df.info())

print("Estações de metrô projetadas")
df = gpd.read_file("dados/GEOSAMPA-MAPA-TREM-E-METRO-SP/estacao_metro_projetada.geojson")
print("Tamanho da tabela:", df.shape,'\n'
)
print(df.info())


print("Estações de trem")
df = gpd.read_file("dados/GEOSAMPA-MAPA-TREM-E-METRO-SP/estacao_trem.geojson")
print("Tamanho da tabela:", df.shape,'\n'
)
print(df.info())

print("Estações de trem projetadas")
df = gpd.read_file("dados/GEOSAMPA-MAPA-TREM-E-METRO-SP/estacao_trem_projetada.geojson")
print("Tamanho da tabela:", df.shape,'\n'
)
print(df.info())

print("Terminal de ônibus")
df = gpd.read_file("dados/GEOSAMPA-MAPA-TREM-E-METRO-SP/terminal_onibus.geojson")
print("Tamanho da tabela:", df.shape,'\n'
)
print(df.info())
# Out:
# Estações de metrô
# Tamanho da tabela: (94, 12)
#
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   94 non-null     object
#  1   cd_identificador                     94 non-null     int32
#  2   cd_identificador_empresa_metro_trem  94 non-null     int32
#  3   nm_estacao_metro_trem                94 non-null     object
#  4   cd_situacao_estacao_metro_trem       94 non-null     int32
#  5   sg_fonte_original                    94 non-null     object
#  6   cd_identificador_linha               94 non-null     int32
#  7   tx_situacao_metro_trem               94 non-null     object
#  8   nm_linha_metro_trem                  94 non-null     object
#  9   nm_empresa_metro_trem                94 non-null     object
# ...
